# %%
'''

 Ready to use for common tasks
 Type conversion: int(), float(), bool()
 Get type of value: type()
 In/out: input(), print()
 Basic calculations: max(), min(), abs(), round()

'''

# global {var} - use this in function or something idk

# functions
def in_to_ft(inches):
    '''
    what it does: convert to feet
    parameters and types: inches
    returns and types: feet
    side effects: no rounding i guess
    exceptions: none
    
    '''
    return inches / 12

# main
if __name__ == "__main__":
    print (in_to_ft(67))
# Out:
# 5.583333333333333
